# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import scipy
import sklearn
import spacy
import re
from nltk.corpus import gutenberg, stopwords
from collections import Counter

# %%
article = pd.read_csv('articles1.csv')
article.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  17283  House Republicans Fret About Winning Their Hea...
# 1           1  17284  Rift Between Officers and Residents as Killing...
# 2           2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3           3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4           4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content
# ...

# %%
article2 = pd.read_csv('articles2.csv')
article2.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0       53293  73471  Patriots Day Is Best When It Digs Past the Her...
# 1       53294  73472  A Break in the Search for the Origin of Comple...
# 2       53295  73474         Obama’s Ingenious Mention of Atticus Finch
# 3       53296  73475         Donald Trump Meets, and Assails, the Press
# 4       53297  73476               Trump: ’I Think’ Hacking Was Russian
#
#   publication             author        date    year  month  url  \
# 0    Atlantic         David Sims  2017-01-11  2017.0    1.0  NaN
# 1    Atlantic            Ed Yong  2017-01-11  2017.0    1.0  NaN
# 2    Atlantic  Spencer Kornhaber  2017-01-11  2017.0    1.0  NaN
# 3    Atlantic    David A. Graham  2017-01-11  2017.0    1.0  NaN
# 4    Atlantic      Kaveh Waddell  2017-01-11  2017.0    1.0  NaN
#
#                                              content
# 0  Patriots Day, Peter Berg’s new thriller that r...
# ...

# %%
article3 = pd.read_csv('articles3.csv')
article3.head()
# Out:
#    Unnamed: 0      id                                              title  \
# 0      103459  151908  Alton Sterling’s son: ’Everyone needs to prote...
# 1      103460  151909  Shakespeare’s first four folios sell at auctio...
# 2      103461  151910  My grandmother’s death saved me from a life of...
# 3      103462  151911  I feared my life lacked meaning. Cancer pushed...
# 4      103463  151912  Texas man serving life sentence innocent of do...
#
#   publication          author        date    year  month  \
# 0    Guardian  Jessica Glenza  2016-07-13  2016.0    7.0
# 1    Guardian             NaN  2016-05-25  2016.0    5.0
# 2    Guardian   Robert Pendry  2016-10-31  2016.0   10.0
# 3    Guardian  Bradford Frost  2016-11-26  2016.0   11.0
# 4    Guardian             NaN  2016-08-20  2016.0    8.0
#
#                                                  url  \
# 0  https://www.theguardian.com/us-news/2016/jul/1...
# 1  https://www.theguardian.com/culture/2016/may/2...
# ...

# %%
article.content[1]
# Out:
# 'After the bullet shells get counted, the blood dries and the votive candles burn out, people peer down from   windows and see crime scenes gone cold: a band of yellow police tape blowing in the breeze. The South Bronx, just across the Harlem River from Manhattan and once shorthand for urban dysfunction, still suffers violence at levels long ago slashed in many other parts of New York City. And yet the city’s efforts to fight it remain splintered, underfunded and burdened by scandal. In the 40th Precinct, at the southern tip of the Bronx, as in other poor, minority neighborhoods across the country, people long hounded for   infractions are crying out for more protection against grievous injury or death. By September, four of every five shootings in the precinct this year were unsolved. Out of the city’s 77 precincts, the 40th has the highest murder rate but the fewest detectives per violent crime, reflecting disparities in staffing that hit hardest in some neighborhoods outside Manha
# ...

# %%
sns.heatmap(article.isnull(),cbar=False,yticklabels=False, cmap='viridis')

# %%
sns.heatmap(article2.isnull(),cbar=False,yticklabels=False, cmap='viridis')

# %%
sns.heatmap(article3.isnull(),cbar=False,yticklabels=False, cmap='viridis')

# %%
article.author.nunique()
# Out:
# 3603

# %%
article.shape
# Out:
# (50000, 10)

# %%
article.publication.unique()
# Out:
# array(['New York Times', 'Breitbart', 'CNN', 'Business Insider', 'Atlantic'], dtype=object)

# %%
article[article['publication'] == 'Breitbart']['author'].nunique()
# Out:
# 387

# %%
article['author'].value_counts().head(10).index
# Out:
# Index(['Breitbart News', 'Pam Key', 'Charlie Spiering', 'Jerome Hudson',
#        'John Hayward', 'Daniel Nussbaum', 'AWR Hawkins', 'Ian Hanchett',
#        'Joel B. Pollak', 'Alex Swoyer'],
#       dtype='object')

# %%
a = article[article['author'] == 'Breitbart News'][['author','content']]

# %%
b = article[article['author'] == 'Pam Key'][['author','content']]

# %%
c = article[article['author'] == 'Charlie Spiering'][['author','content']]

# %%
d = article[article['author'] == 'Jerome Hudson'][['author','content']]

# %%
e = article[article['author'] == 'John Hayward'][['author','content']]

# %%
f = article[article['author'] == 'Daniel Nussbaum'][['author','content']]

# %%
g = article[article['author'] == 'AWR Hawkins'][['author','content']]

# %%
h = article[article['author'] == 'Ian Hanchett'][['author','content']]

# %%
i = article[article['author'] == 'Joel B. Pollak'][['author','content']]

# %%
j = article[article['author'] == 'Alex Swoyer'][['author','content']]

# %%
# Utility function for standard text cleaning.
def text_cleaner(text):
    # Visual inspection identifies a form of punctuation spaCy does not
    # recognize: the double dash '--'.  Better get rid of it now!
    text = re.sub(r'--',' ',text)
    text = re.sub("[\[].*?[\]]", "", text)
    text = ' '.join(text.split())
    return text

# %%
nlp = spacy.load('en')

# %%
a['content'] = a['content'].apply(text_cleaner)

# %%
breitbart_doc = a['content'].apply(nlp)

# %%
b['content'] = b['content'].apply(text_cleaner)

# %%
pam_doc = b['content'].apply(nlp)

# %%
c['content'] = c['content'].apply(text_cleaner)

# %%
charlie_doc = c['content'].apply(nlp)

# %%
d['content'] = d['content'].apply(text_cleaner)

# %%
jerome_doc = d['content'].apply(nlp)

# %%
e['content'] = e['content'].apply(text_cleaner)

# %%
john_doc = e['content'].apply(nlp)

# %%
f['content'] = f['content'].apply(text_cleaner)

# %%
daniel_doc = f['content'].apply(nlp)

# %%
g['content'] = g['content'].apply(text_cleaner)

# %%
awr_doc = g['content'].apply(nlp)

# %%
h['content'] = h['content'].apply(text_cleaner)

# %%
ian_doc = h['content'].apply(nlp)

# %%
i['content'] = i['content'].apply(text_cleaner)

# %%
joel_doc = i['content'].apply(nlp)

# %%
j['content'] = j['content'].apply(text_cleaner)

# %%
alex_doc = j['content'].apply(nlp)

# %%
entities = list(joel_doc[0:100].ents)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-88d77b86eefe> in <module>()
# ----> 1 entities = list(joel_doc[0:100].ents)
#
# C:\Users\etallen127\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'ents'

# %%
macbeth = gutenberg.raw('shakespeare-macbeth.txt')

# %%
macbeth
# Out:
# "[The Tragedie of Macbeth by William Shakespeare 1603]\n\n\nActus Primus. Scoena Prima.\n\nThunder and Lightning. Enter three Witches.\n\n  1. When shall we three meet againe?\nIn Thunder, Lightning, or in Raine?\n  2. When the Hurley-burley's done,\nWhen the Battaile's lost, and wonne\n\n   3. That will be ere the set of Sunne\n\n   1. Where the place?\n  2. Vpon the Heath\n\n   3. There to meet with Macbeth\n\n   1. I come, Gray-Malkin\n\n   All. Padock calls anon: faire is foule, and foule is faire,\nHouer through the fogge and filthie ayre.\n\nExeunt.\n\n\nScena Secunda.\n\nAlarum within. Enter King Malcome, Donalbaine, Lenox, with\nattendants,\nmeeting a bleeding Captaine.\n\n  King. What bloody man is that? he can report,\nAs seemeth by his plight, of the Reuolt\nThe newest state\n\n   Mal. This is the Serieant,\nWho like a good and hardie Souldier fought\n'Gainst my Captiuitie: Haile braue friend;\nSay to the King, the knowledge of the Broyle,\nAs thou didst leaue it\n\n   Cap
# ...

# %%
a = []

# %%
from collections import Counter

# Utility function to calculate how frequently words appear in the text.
def word_frequencies(text, include_stop=True):
    
    # Build a list of words.
    # Strip out punctuation and, optionally, stop words.
    words = []
    for token in text:
        if not token.is_punct and (not token.is_stop or include_stop):
            words.append(token.text)
            
    # Build and return a Counter object containing word counts.
    return Counter(words)

# %%
word_frequencies(joel_doc, include_stop=False).most_common(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-3c3e6659a99e> in <module>()
# ----> 1 word_frequencies(joel_doc, include_stop=False).most_common(10)
#
# <ipython-input-93-e59885082256> in word_frequencies(text, include_stop)
#       8     words = []
#       9     for token in text:
# ---> 10         if not token.is_punct and (not token.is_stop or include_stop):
#      11             words.append(token.text)
#      12
#
# AttributeError: 'spacy.tokens.doc.Doc' object has no attribute 'is_punct'

# %%
tdf = pd.concat([a,b,c,d,e,f,g,h,i,j])

# %%
 p = [entity for entity in(joel_doc.apply(lambda x: x.entity))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-65e4769888e0> in <module>()
# ----> 1 p = [entity for entity in(joel_doc.apply(lambda x: x.entity))]
#
# C:\Users\etallen127\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66440)()
#
# <ipython-input-90-65e4769888e0> in <lambda>(x)
# ----> 1 p = [entity for entity in(joel_doc.apply(lambda x: x.entity))]
#
# AttributeError: 'spacy.tokens.doc.Doc' object has no attribute 'entity'

# %%
p
# Out:
# [(Gold Star,
#   Southern California,
#   Irvine,
#   Sunday,
#   Northwood Gratitude,
#   Honor Memorial,
#   the U. S.,
#   Iraq,
#   Afghanistan,
#   2003,
#   The Los Angeles Times,
#   Ten,
#   Gold Star,
#   about 300,
#   each year,
#   first,
#   American,
#   Afghanistan,
#   Iraq,
#   2003,
#   Afghanistan,
#   Iraq,
#   Southern California,
#   Irvine,
#   the week before Memorial Day,
#   the week,
#   Independence Day,
#   Honor Memorial,
#   Afghanistan,
#   Iraq,
#   Americans,
#   today,
#   Operation Enduring Freedom,
#   Operation Iraqi Freedom,
#   Operation New Dawn,
#   One,
#   California,
#   Memorial Day,
#   the Golden State,
#   Bakersfield,
#   Fort Rosecrans,
#   Golden Gate,
#   Los Angeles,
#   Miramar, Riverside,
#   Sacramento Valley,
#   San Francisco,
#   San Joaquin Valley,
#   Joel B. Pollak,
#   Breitbart News,
#   2016,
#   The Inside Story of a Revolution,
#   Twitter),
#  (Donald Trump,
#   the Wall Street Journal,
#   Wednesday evening,
# ...

# %%
tdf.shape
# Out:
# (8652, 2)

# %%
tdf['content'].head()
# Out:
# 7817    Advocates who want America’s immigration laws ...
# 7858    This story first appeared on Fox 5 New York:  ...
# 7872    In a column for the Hollywood Reporter, Senior...
# 7887    On the Tuesday edition of Breitbart News Daily...
# 7912    Conservative radio host Rush Limbaugh question...
# Name: content, dtype: object
